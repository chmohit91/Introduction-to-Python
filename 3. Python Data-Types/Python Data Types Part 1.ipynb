# %% [markdown]
# # How Machine code are interpreted ?

# %%
a = 10 #--------> 1010
b = 20 #--------> 10100
c = a/b # float division (the result will be in machine code only)
print(c)  #here i am printing the value

#output will be generated in the machine code now again my interpreter will help to convert the result
# which is in machine code back to the high level language that we know
# Out:
# 0.5

# %%
2+3
# Out:
# 5

# %%
2-3
# Out:
# -1

# %%
3*20
# Out:
# 60

# %%
3+2.5 ------> 3.0 + 2.5

# %% [markdown]
# ### Type of Error
#
# - Compile Time Error
# - Run Time Error
# - Logical Error (Print the result but the result will be wrong)
#
# ### Compile Time Error :-
#     - The error we get at the time of the compilation (when conversion of source code to byte code is happening)
#         - Syntax
#         - Indentation (space)

# %%
for i in range(0,5)
    print(i)
# Out:
#   Cell In[10], line 1
#     for i in range(0,5)
#                        ^
# SyntaxError: expected ':'

# %%
a  = 'Mayank'

for i in a:
print(i)
# Out:
#   Cell In[9], line 4
#     print(i)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 3

# %% [markdown]
# ### Run Time Error Or Exceptions:-
#
#     -The run time error are those error that are syntactically correct but they craete some issue while conversion of the bytecode to machine code
#
#             - Name error
#             - Type error
#             - Value error
#             - index error
#             - file not found error
#             - stop iteration
#             - key error etc

# %%
a = 10
b = 20
c = a+b
print(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 b = 20
#       3 c = a+b
# ----> 4 print(d)
#
# NameError: name 'd' is not defined

# %%
1+'mayank'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 1+'mayank'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
while True:
    print('mayank')

# %% [markdown]
# mayank
#
# mayank
#
# mayank
#
# mayank
#
# mayank
#
# mayank
#
# mayank
#
# mayank
#
# mayank
#
# mayank
#
# mayank
#
# mayank
#
# mayank
#
# mayank
#
# and so on
#
#
#
# ### **KeyboardInterrupt**
#                    Traceback (most recent call last)
# <ipython-input-3-f52f8d97f62f> in <cell line: 1>()
#       1 while True:
# ----> 2     print('mayank')
#
# 3 frames
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.10/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# Example for logical error
a = 10
b = 20

# want to add two numbers
c = a-b
print(c)
# Out:
# -10

# %%
import pandas as pd
a = pd.read_csv('titanic')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 import pandas as pd
# ----> 2 a = pd.read_csv('titanic')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %% [markdown]
# # Variable
#
# - A container that is going to store a particular value in it and we can change the stored value in the variable at any point of time
# - A variable is going to retain the last value assigned to it till the next assignmnet is done
# - a variable name should always be in lowercase (small letter)

# %%
a = 10
a
# Out:
# 10

# %%
b = 20

# %%
b = 30

# %%
d = 10.0
e = 'Mayank'
f = 6+1j

# %% [markdown]
# ## Constants
#
# - Constants aer also variable but we have set our mind that we will never change their value

# %%
PI = 3.14
SPEED_OF_LIGHT = 3e8

# %%
PI
# Out:
# 3.14

# %%
SPEED_OF_LIGHT
# Out:
# 300000000.0

# %% [markdown]
# ### Type Function
#
# - This function is used to actually tell that which datatype is stored in a particular variable

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(d))
# Out:
# <class 'float'>

# %%
print(type(e))
# Out:
# <class 'str'>

# %%
print(type(f))
# Out:
# <class 'complex'>

# %% [markdown]
# ### Id function
#
# - Tell me the the memory space location associated with the value

# %%
print(id(a))
# Out:
# 140709933847624

# %%
print(id(b))
# Out:
# 140709933848264

# %%
a = 1

# %%
type(a)
# Out:
# int

# %%
id(a)
# Out:
# 140709933847336

# %%
a = 2

# %%
id(a)
# Out:
# 140709933847368

# %% [markdown]
# # Data-types
#
# - A data-type is a type identifier of the values that a variable is having
#
#
# ## Different types of Data
#
# - integer (int)
# - float (float)
# - complex(complex)
# - string (str)
# - boolean (bool)
# - None

# %% [markdown]
# #### Integer
#
# - Any number +ve, -ve or 0, without a decimal value is known as an integer

# %%
a = 100000
b = -166687888
c = 0

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# int

# %%
type(c)
# Out:
# int

# %% [markdown]
# #### Float
#
# - Any value +ve, -ve or 0, with a decimal is known as float
# - interanally the float values are store in exponential

# %%
a = 10.1  #101e-1
# Out:
# 30

# %%
101e-1
# Out:
# 10.1

# %%
101/10 -----> 101e-1

# %%
b = 103.75

# %%
10375e-2 -----10375/100
# Out:
# 103.75

# %%
1e-2   ---1/100
# Out:
# 0.01

# %%
1e-3 #-----1/1000
# Out:
# 0.001

# %%
e-1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 e-1
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
a = 3e3
a
# Out:
# 3000.0

# %%
type(a)
# Out:
# float
